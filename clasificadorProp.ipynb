# %%
#Librerias usadas en este programa
import pandas as pd
import numpy as np
import csv
import os
import nltk
import seaborn as sns
import matplotlib.pyplot as plt
import re
from sklearn import svm
from imblearn.under_sampling import RandomUnderSampler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
#Ejecutar esta linea de abajo solo una vez para tener las stopwords en español
#nltk.download('stopwords')
from nltk.corpus import stopwords
import requests
from bs4 import BeautifulSoup

# %%
#Bloque que realiza web scraping y almacena los textos divididos por carpeta dependiendo de sus tags
i = 1
contador = 0
while i < 27:
    URL = 'https://votainteligente.cl/propuestas/?page='+str(i)
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id='posts')
    job_elems = results.find_all('div', class_='post')
    for job_elem in job_elems:
        try:
            category = job_elem.find('a')['href']
            category = re.search("clasification=(.*)", category)
            category = category.group(1)
            title = job_elem.find('h4')
            title = title.text
            title = re.sub("/", "-", title)
            leer_mas = job_elem.find('a', class_='btn btn-blue pull-right')['href']
            URL = 'https://votainteligente.cl'+leer_mas
            page = requests.get(URL)
            soup = BeautifulSoup(page.content, 'html.parser')
            cuerpo = soup.find('div', class_='col-md-12')
            cuerpo = cuerpo.find('p')
            cuerpo = cuerpo.text

            politica = ['politica', 'justicia', 'transparencia','democracia','institucionespublicas']
            medioambiente = ['medioambiente','medio_ambiente','sustentabilidad','recursosnaturales','emergencia']
            social = ['diversidad','derechos','asistencia','proteccion_y_familia','participacion','genero','migracion','proteccionsocial','seguridad','pensiones','pueblosoriginarios','medios','probidad','proteccionanimal','derechoshumanos','espaciospublicos','infancia','terceraedad']
            sanidad = ['salud']
            culturayciencia = ['cultura','deporte','tecnologia','ciencias','energia','ocio']
            interior = ['transporte','educacion','trabajo','empleo','economia','descentralizacion','emprendimiento','educacion_y_trabajo']

            if category in politica:
                if not os.path.exists('./dataset/'+'politica'):
                    os.makedirs('./dataset/'+'politica')
                f= open('./dataset/'+'politica'+'/'+title,"w+")
                f.write(cuerpo)
                contador+=1
                f.close()
            if category in medioambiente:
                if not os.path.exists('./dataset/'+'medioambiente'):
                    os.makedirs('./dataset/'+'medioambiente')
                f= open('./dataset/'+'medioambiente'+'/'+title,"w+")
                f.write(cuerpo)
                contador+=1
                f.close()
            if category in social:
                if not os.path.exists('./dataset/'+'social'):
                    os.makedirs('./dataset/'+'social')
                f= open('./dataset/'+'social'+'/'+title,"w+")
                f.write(cuerpo)
                contador+=1
                f.close()
            if category in sanidad:
                if not os.path.exists('./dataset/'+'sanidad'):
                    os.makedirs('./dataset/'+'sanidad')
                f= open('./dataset/'+'sanidad'+'/'+title,"w+")
                f.write(cuerpo)
                contador+=1
                f.close()
            if category in culturayciencia:
                if not os.path.exists('./dataset/'+'culturayciencia'):
                    os.makedirs('./dataset/'+'culturayciencia')
                f= open('./dataset/'+'culturayciencia'+'/'+title,"w+")
                f.write(cuerpo)
                contador+=1
                f.close()
            if category in interior:
                if not os.path.exists('./dataset/'+'interior'):
                    os.makedirs('./dataset/'+'interior')
                f= open('./dataset/'+'interior'+'/'+title,"w+")
                f.write(cuerpo)
                contador+=1
                f.close()
        except:
            continue
    print('Pagina '+ str(i) + ' scrapeada')
    i += 1
print(f'Numero total de textos = {contador}')
# Out:
# Pagina 1 scrapeada
# Pagina 2 scrapeada
# Pagina 3 scrapeada
# Pagina 4 scrapeada
# Pagina 5 scrapeada
# Pagina 6 scrapeada
# Pagina 7 scrapeada
# Pagina 8 scrapeada
# Pagina 9 scrapeada
# Pagina 10 scrapeada
# Pagina 11 scrapeada
# Pagina 12 scrapeada
# Pagina 13 scrapeada
# Pagina 14 scrapeada
# Pagina 15 scrapeada
# Pagina 16 scrapeada
# Pagina 17 scrapeada
# Pagina 18 scrapeada
# Pagina 19 scrapeada
# Pagina 20 scrapeada
# Pagina 21 scrapeada
# Pagina 22 scrapeada
# Pagina 23 scrapeada
# Pagina 24 scrapeada
# Pagina 25 scrapeada
# Pagina 26 scrapeada
# Numero total de textos = 748

# %%
#En este bloque se leen todos los archivos txt y se incluyen en un dataframe
col_names =  ['category', 'title', 'content'] 
df  = pd.DataFrame(columns = col_names) 
path = r"dataset\culturayciencia"
categoria= "culturayciencia"
directories = os.listdir( path )
 

for file in directories:
    print("El nombre de archivo es: "+ file)
    print("La categoria del archivo es: "+ categoria)
    objText = open(path+"\\"+file,"r",encoding='ANSI')
    lstLines = objText.read()
    titulo = file
    cuerpo = re.findall(r".*",lstLines)
    print("El titulo es: "+ titulo)
    print("El cuerpo es: "+ cuerpo[0])
    new_row = {'category':categoria, 'title':titulo, 'content':cuerpo[0]}
    df = df.append(new_row, ignore_index=True)
    print()

path = r"dataset\interior"
categoria= "interior"
directories = os.listdir( path )
 

for file in directories:
    print("El nombre de archivo es: "+ file)
    print("La categoria del archivo es: "+ categoria)
    objText = open(path+"\\"+file,"r",encoding='ANSI')
    lstLines = objText.read()
    titulo = file
    cuerpo = re.findall(r".*",lstLines)
    print("El titulo es: "+ titulo)
    print("El cuerpo es: "+ cuerpo[0])
    new_row = {'category':categoria, 'title':titulo, 'content':cuerpo[0]}
    df = df.append(new_row, ignore_index=True)
    print()

path = r"dataset\medioambiente"
categoria= "medioambiente"
directories = os.listdir( path )
 

for file in directories:
    print("El nombre de archivo es: "+ file)
    print("La categoria del archivo es: "+ categoria)
    objText = open(path+"\\"+file,"r",encoding='ANSI')
    lstLines = objText.read()
    titulo = file
    cuerpo = re.findall(r".*",lstLines)
    print("El titulo es: "+ titulo)
    print("El cuerpo es: "+ cuerpo[0])
    new_row = {'category':categoria, 'title':titulo, 'content':cuerpo[0]}
    df = df.append(new_row, ignore_index=True)
    print()

path = r"dataset\politica"
categoria= "politica"
directories = os.listdir( path )
 

for file in directories:
    print("El nombre de archivo es: "+ file)
    print("La categoria del archivo es: "+ categoria)
    objText = open(path+"\\"+file,"r",encoding='ANSI')
    lstLines = objText.read()
    titulo = file
    cuerpo = re.findall(r".*",lstLines)
    print("El titulo es: "+ titulo)
    print("El cuerpo es: "+ cuerpo[0])
    new_row = {'category':categoria, 'title':titulo, 'content':cuerpo[0]}
    df = df.append(new_row, ignore_index=True)
    print()

path = r"dataset\sanidad"
categoria= "sanidad"
directories = os.listdir( path )
 

for file in directories:
    print("El nombre de archivo es: "+ file)
    print("La categoria del archivo es: "+ categoria)
    objText = open(path+"\\"+file,"r",encoding='ANSI')
    lstLines = objText.read()
    titulo = file
    cuerpo = re.findall(r".*",lstLines)
    print("El titulo es: "+ titulo)
    print("El cuerpo es: "+ cuerpo[0])
    new_row = {'category':categoria, 'title':titulo, 'content':cuerpo[0]}
    df = df.append(new_row, ignore_index=True)
    print()

path = r"dataset\social"
categoria= "social"
directories = os.listdir( path )
 

for file in directories:
    print("El nombre de archivo es: "+ file)
    print("La categoria del archivo es: "+ categoria)
    objText = open(path+"\\"+file,"r",encoding='ANSI')
    lstLines = objText.read()
    titulo = file
    cuerpo = re.findall(r".*",lstLines)
    print("El titulo es: "+ titulo)
    print("El cuerpo es: "+ cuerpo[0])
    new_row = {'category':categoria, 'title':titulo, 'content':cuerpo[0]}
    df = df.append(new_row, ignore_index=True)
    print()
        
df['category_id'] = df['category'].factorize()[0]
df
# Out:
# El nombre de archivo es: Acceso a la cultura y el conocimiento
# La categoria del archivo es: culturayciencia
# El titulo es: Acceso a la cultura y el conocimiento
# El cuerpo es: El sistema de derechos de autor se encuentra desbalanceado en favor de los intereses de los titulares en detrimento de los derechos del público
#
# El nombre de archivo es: Acercando a la Biblioteca
# La categoria del archivo es: culturayciencia
# El titulo es: Acercando a la Biblioteca
# El cuerpo es: Las bibliotecas publicas no son usadas por los jóvenes, no la aprovechan, por lo que hay que motivar a los jóvenes a usarla, a través de la creación de talleres para jóvenes y niños constantes.
#
# El nombre de archivo es: Arte, cultura
# La categoria del archivo es: culturayciencia
# El titulo es: Arte, cultura
# El cuerpo es: Valorización del arte en chile.
#
# El nombre de archivo es: Cambio de paradigma por parte del estado en la generación de energía para todos los Chilenos,
# La categoria del archivo es: culturayciencia
# El titulo es: Cambio de paradigma por parte del estado en la generación de energía para todos los Chilenos,
# El cuerpo es: Contaminación de las ciudades y altos costos de la energía eléctrica.
#
# El nombre de archivo es: CAMBIO DE SISTEMA EDUCATIVO
# La categoria del archivo es: culturayciencia
# El titulo es: CAMBIO DE SISTEMA EDUCATIVO
# El cuerpo es:
#
# El nombre de archivo es: Carteles de Candidatos Presidenciales
# La categoria del archivo es: culturayciencia
# El titulo es: Carteles de Candidatos Presidenciales
# El cuerpo es: Que la plata que se gasta en letreros para las elecciones sean gastados en algo útil para las personas.
#
# El nombre de archivo es: Compromiso con las ciencias
# La categoria del archivo es: culturayciencia
# El titulo es: Compromiso con las ciencias
# El cuerpo es:
#
# El nombre de archivo es: Cultura para todos
# La categoria del archivo es: culturayciencia
# El titulo es: Cultura para todos
# El cuerpo es: El poco apoyo a la cultura
#
# El nombre de archivo es: Deportes mas alla del Futbol
# La categoria del archivo es: culturayciencia
# El titulo es: Deportes mas alla del Futbol
# El cuerpo es: Poca importancia de Deportes fuera del Futbol
#
# El nombre de archivo es: Desigualdad en tamaño de canchas
# La categoria del archivo es: culturayciencia
# El titulo es: Desigualdad en tamaño de canchas
# El cuerpo es: Las canchas de fútbol son mucho mas grandes comparadas con las otras, por eso proponemos la solución de agrandar las canchas de otros deportes e igualar el tamaño, porque es muy incomodo jugar en canchas pequeñas.
#
# El nombre de archivo es: Discriminación por las diferencias de culturas no demasiado tiempo libre para las personas
# La categoria del archivo es: culturayciencia
# El titulo es: Discriminación por las diferencias de culturas no demasiado tiempo libre para las personas
# El cuerpo es: No a la discriminación Respetar las culturas si son diferentesCrear mas espacios deportivos y dejar tiempo libre para las personas de trabajos duros.
#
# El nombre de archivo es: Eliminación del rodeo como una actividad deportiva en la cual se permite el sufrimiento animal
# La categoria del archivo es: culturayciencia
# El titulo es: Eliminación del rodeo como una actividad deportiva en la cual se permite el sufrimiento animal
# El cuerpo es: Gran debate ha causado los últimos años en Chile la existencia del rodeo y el uso de animales que se efectúa en el marco del mismo. Se ha señalado que el rodeo sería un “deporte nacional”, cuestión recogida en la Ley N° 20.380, pese a no cumplir con los requisitos establecidos por la Ley N° 19.712 “Ley del deporte”, siendo actualmente un espacio público de entretención. Adicionalmente, son diversas las evidencias que han llevado a comprobar que en este espectáculo público se hiere, hostiliza y maltrata al animal involucrado, situación que contradice la preocupación nacional e internacional en torno al animal. Además, voces de alerta han surgido en torno a mantener, con el pretexto cultural, un espacio que normaliza la violencia hacia otro ser vivo, cuestión que podría perjudicar el desarrollo identitario de nuestra sociedad, permitiendo prácticas de agresión, que podrían luego servir de base para justificar actos de maltrato hacia otros animales, humanos y no humanos.
#
# El nombre de archivo es: Espacios limpios
# La categoria del archivo es: culturayciencia
# El titulo es: Espacios limpios
# El cuerpo es: Velar por la limpieza de lugares públicos
#
# El nombre de archivo es: Falta de acceso al uso de la tecnología en colegios rurales le impide a los alumnos mejorar sus a
# La categoria del archivo es: culturayciencia
# El titulo es: Falta de acceso al uso de la tecnología en colegios rurales le impide a los alumnos mejorar sus a
# El cuerpo es: Mejorar las políticas públicas para lograr que todas las escuelas de Chile queden comunicadas a través de internet y puedan usar la tecnología disponible el las escuelas de las ciudades del centro del país, y así dar equidad a sus alumnos en cuanto a la calidad de la educación.
#
# El nombre de archivo es: Fomentar y apoyar el deporte
# La categoria del archivo es: culturayciencia
# El titulo es: Fomentar y apoyar el deporte
# El cuerpo es: . Mínimo fomento del deporte.
#
# El nombre de archivo es: Futuro Chileno
# La categoria del archivo es: culturayciencia
# El titulo es: Futuro Chileno
# El cuerpo es: Enseñarle al Chileno que el Turismo en una forma de vida
#
# El nombre de archivo es: LA TECNOLOGÍA NOS HACE PERDER LA CULTURA
# La categoria del archivo es: culturayciencia
# El titulo es: LA TECNOLOGÍA NOS HACE PERDER LA CULTURA
# El cuerpo es: CON LOS AVANCES TECNOLOGICOS YA NO HAY CONTACTO DIRECTO CON EL ENTORNO CERCANO, POR LO QUE SE DEBERIA LIMITAR EL USO DE OBJETOS TECNOLÓGICOS.
#
# El nombre de archivo es: Ley Nikola Tesla
# La categoria del archivo es: culturayciencia
# El titulo es: Ley Nikola Tesla
# El cuerpo es: encontrar medidas ecológicas y energéticas renovables y de libre acceso para la sociedad y la humanidad
#
# El nombre de archivo es: Liceos para deportistas
# La categoria del archivo es: culturayciencia
# El titulo es: Liceos para deportistas
# El cuerpo es: Deportistas de élite
#
# El nombre de archivo es: MARCHANDO HACIA LA LIBERACION ENERGETICA DE LOS HOGARES
# La categoria del archivo es: culturayciencia
# El titulo es: MARCHANDO HACIA LA LIBERACION ENERGETICA DE LOS HOGARES
# El cuerpo es: Es el alto costo a nivel domiciliario de la energía, sobre todo en Electricidad y Calefacción. La captura de los clientes por Monopolios como son las distribuidoras de electricidad y la licitación a las grandes empresas en caso de instalar sistemas autonomos o de ahorro de energía, junto con la construcción de las poblaciones.
#
# El nombre de archivo es: Mayor acceso a espacios recreativos, culturales y deportivos
# La categoria del archivo es: culturayciencia
# El titulo es: Mayor acceso a espacios recreativos, culturales y deportivos
# El cuerpo es: -Ampliar los terrenos y espacios de campos o canchas deportivas al aire libre.-Habilitar más espacios como canchas o gimnasios para talleres deportivos.-Que todo espacio con una finalidad recreativa, cultural o deportiva sea de libre acceso (gratuito y para toda la sociedad).-Plazas y parques de todas las comunas cuenten con juegos recreativos de acceso universal.-Museos y exposiciones sean con entrada liberada, siendo requisito mostrar la cédula de identidad para mayor seguridad.-Lugares considerados patrimonio cultural y que cuentan con visitas guiadas durante todo el año, sean gratuitos, ya que todas las personas tienen derecho a aprender de su cultura.
#
# El nombre de archivo es: MEJOR INTERCONECTIVIDAD
# La categoria del archivo es: culturayciencia
# El titulo es: MEJOR INTERCONECTIVIDAD
# El cuerpo es: MEJOR CONECTIVIDAD PARA TODAS LAS PERSONASSEÑALES MÁS FLUIDAS DE REDES (WIFI) EN SECTORES RURALES
#
# El nombre de archivo es: Mejores ciudades para todos
# La categoria del archivo es: culturayciencia
# El titulo es: Mejores ciudades para todos
# El cuerpo es: Problema: Nadie cuida el medioambiente, además no se aprovecha el tiempo libre Causas: La gente bota basura en la calle o cualquier parte que no corresponde, falta enseñanza, además faltan lugares para aprovechar el tiempo libre. Efectos: Gente amargada e infeliz por una ciudad sucia y por la falta de espacios de entretenimiento.Solución: 1.Abrir más museos y teatros para aprender más cultura antigua. 2.Cambiar los botes de basuras por bolsas de reciclaje, aumentando cada bolsa en cada sector. 3.Agregar alguna asignatura que le enseñe a los niños a no contaminar
#
# El nombre de archivo es: Mejores Quesos para Chile
# La categoria del archivo es: culturayciencia
# El titulo es: Mejores Quesos para Chile
# El cuerpo es: Hay poca variedad de quesos y el gauda es muy desabrido.
#
# El nombre de archivo es: Menos Tecnología, más comunicación
# La categoria del archivo es: culturayciencia
# El titulo es: Menos Tecnología, más comunicación
# El cuerpo es: Volver a estar conectados con nuestro entorno, jugar más y chatear menos, ir a los parques, no utilizar el celular mientras conducen, descansar y no utilizar el celular de noche para dormir las horas que corresponden.
#
# El nombre de archivo es: METRO PARA LA PINTANA
# La categoria del archivo es: culturayciencia
# El titulo es: METRO PARA LA PINTANA
# El cuerpo es: LLEVAMOS MUCHOS AÑOS ESPERANDO UN METRO, Y QUEREMOS QUE CON EL O LA [email protected] [email protected] LOGRE CREAR U OBTENER LA NUEVA LINEA PARA LA PINTANA. PARA TENER ACCESO MAS RAPIDO ENTRE LAS COMUNAS UNIDAS.
#
# El nombre de archivo es: Más canchas de basquetbol y menos de futbol
# La categoria del archivo es: culturayciencia
# El titulo es: Más canchas de basquetbol y menos de futbol
# El cuerpo es: canchas de basquetbol
#
# El nombre de archivo es: MÁS CULTURA
# La categoria del archivo es: culturayciencia
# El titulo es: MÁS CULTURA
# El cuerpo es: Obras públicas, lugares recreativos
#
# El nombre de archivo es: Más cultura para un Chile mejor
# La categoria del archivo es: culturayciencia
# El titulo es: Más cultura para un Chile mejor
# El cuerpo es: Realizar intervenciones urbanas masivas para fomentar la cultura, no solo en Santiago sino en todas las comunas de Chile, organizadas por los propios ciudadanos.
#
# El nombre de archivo es: Más deporte y de mejor calidad
# La categoria del archivo es: culturayciencia
# El titulo es: Más deporte y de mejor calidad
# El cuerpo es: Falta de áreas en las cuales practicar deporte
#
# El nombre de archivo es: Más entrega de recursos a los deportistas por parte del Estado Chileno
# La categoria del archivo es: culturayciencia
# El titulo es: Más entrega de recursos a los deportistas por parte del Estado Chileno
# El cuerpo es: Falta de recursos para los Deportistas que representan nuestro país
#
# El nombre de archivo es: Más espacios públicos y comunitarios para la práctica del deporte y vida sana
# La categoria del archivo es: culturayciencia
# El titulo es: Más espacios públicos y comunitarios para la práctica del deporte y vida sana
# El cuerpo es: Implementar políticas públicas para incentivar que las municipalidades, juntas de vecinos creen y mantengan espacios deportivos y áreas verdes en las poblaciones.
#
# El nombre de archivo es: Más participación y actividades recreativas
# La categoria del archivo es: culturayciencia
# El titulo es: Más participación y actividades recreativas
# El cuerpo es: -Más actividades en las plazas, que sean recreativas como scout, deporte, junta de vecinos, etc.-Más participación de los jóvenes en actividades comunales. -Más aplicaciones que enseñen sobre la tecnología.
#
# El nombre de archivo es: Más Áreas Verdes
# La categoria del archivo es: culturayciencia
# El titulo es: Más Áreas Verdes
# El cuerpo es: Que existan más áreas verdes para que podamos hacer deporte al aire libre y poder jugar.
#
# El nombre de archivo es: Política Nacional de Deporte - Visión de Estado a Largo Plazo
# La categoria del archivo es: culturayciencia
# El titulo es: Política Nacional de Deporte - Visión de Estado a Largo Plazo
# El cuerpo es: Carencia de una política de Estado en materia deportiva.
#
# El nombre de archivo es: Por una vida con mas tiempo
# La categoria del archivo es: culturayciencia
# El titulo es: Por una vida con mas tiempo
# El cuerpo es: Debido a que la mayor parte del tiempo las personas la pasan trabajando o estudiando, se debería establecer menos horas de trabajo y de clases (hasta la 13:00 de la tarde), solo para los alumnos de la educación media.
#
# El nombre de archivo es: Prohibición de las carreras de galgos
# La categoria del archivo es: culturayciencia
# El titulo es: Prohibición de las carreras de galgos
# El cuerpo es: En Chile, las carreras de perros –en especial, de galgos- siguen siendo una práctica común. Muchas veces clandestina, es una actividad que genera un desgaste físico y psicológico del animal, resultando en un abandono de mismo,, que ha sido utilizado en una etapa precoz de su vida y en un estado de deterioro que requiere necesariamente de cuidados especiales veterinarios (primarios y etológicos). Además, se genera un negocio clandestino, en el cual se fomenta la ludopatía y el comercio ilegal de animales. Se requiere, tal como lo han realizado países en los que esta actividad se encuentra presente, una regulación que prohíba esta actividad. Durante los últimos años, España y Argentina han sido pioneros en proponer una regulación clara y práctica.
#
# El nombre de archivo es: RECREACIÓN Y DEPORTE ACTIVO
# La categoria del archivo es: culturayciencia
# El titulo es: RECREACIÓN Y DEPORTE ACTIVO
# El cuerpo es: MÁS LUGARES DE ESPARCIMIENTOMAS Y MEJORES CICLOVÍAS (QUE SE RESPETEN)SUBVENCIONAR Y FOMENTAR MÁS FERIAS CULTURALES GRATUITAS EN PROVINCIAS
#
# El nombre de archivo es: Recursos a deportistas que quieren crecer a nivel nacional
# La categoria del archivo es: culturayciencia
# El titulo es: Recursos a deportistas que quieren crecer a nivel nacional
# El cuerpo es: En chile hay un gran problema por parte del deporte ya que al no ser futbol no hay apoyo sea monetario o no.Mi propuesta seria mayor fomento de deporte en todo medio de comunicacion al igual que ayudar con recursos a los deportistas que no puedan costearse algunos gastos que se necesitan a algun campeonatos ya sean nacionales o internacionales ya que al no realizarse estas ayudas de parte del gobierno el deporte chile no progresa de buena manera las personas que surgen son solo las que tienen recursos o posibilidad de vivir en regiones mas desarrolladas deportivamente y los niños con talento estan esperando surgir no pueden ya que estan aislados de ayuda y sus recurson no son suficientes.En los deportes como voleyball, basquetball, tenis de mesa,handbal, etc.Se aprecia su atencion.ATTE: Un niño deportista de 15 años.
#
# El nombre de archivo es: Tecnología y comunicación para todos
# La categoria del archivo es: culturayciencia
# El titulo es: Tecnología y comunicación para todos
# El cuerpo es: Problema: No todos tienen buena tecnología y comunicaciónCausas: Falta de recursos para tecnologíaEfectos: Que las personas no saben si sus familiares están bien o malSolución: Que todos tengas acceso a la tecnología y comunicación con internet gratuito.
#
# El nombre de archivo es: The festival music
# La categoria del archivo es: culturayciencia
# El titulo es: The festival music
# El cuerpo es: Financiar eventos musicales en distintas localidades del país con participación de artistas nacionales, regionales y locales.
#
# El nombre de archivo es: Toda Cultura Merece Respeto
# La categoria del archivo es: culturayciencia
# El titulo es: Toda Cultura Merece Respeto
# El cuerpo es: Que se respeten todas las culturas de inmigrantes.
#
# El nombre de archivo es: VIDEOJUEGOS PARA SAN FERNANDO
# La categoria del archivo es: culturayciencia
# El titulo es: VIDEOJUEGOS PARA SAN FERNANDO
# El cuerpo es: QUE SE CREE UN ESPACIO FISICO DENTRO DE LA CIUDAD DONDE SE PUEDAN LLEVAR A CABO CAMPEONATOS DE VIDEO JUEGOS.
#
# El nombre de archivo es: ¡CUIDADO CON LA TECNOLOGÍA!
# La categoria del archivo es: culturayciencia
# El titulo es: ¡CUIDADO CON LA TECNOLOGÍA!
# El cuerpo es: CREAR UNA CAMPAÑA PREVENTIVA EN LA ESCUELA, A TRAVES DE AFICHES, VISITAS DE MEDICOS Y OFTALMOLOGOS, ETC. , QUE INFORMEN SOBRE LOS RIESGOS DE SALUD QUE PORVOCA EL USO EXCESIVO DE CLEULARES, TABLETS, COMPUTADORES, ETC.
#
# El nombre de archivo es: ¡MENOS CLASES, MAS JUEGOS!
# La categoria del archivo es: culturayciencia
# El titulo es: ¡MENOS CLASES, MAS JUEGOS!
# El cuerpo es: HACER UNA MARCHA PARA QUE HAGNA UNA LEY PARA QUE SEAN MENOS HORAS LAS QUE ESTAMOS EN LA ESCUELA Y ASI TENER TIEMPO LIBRE.
#
# El nombre de archivo es: ¡SALGAMOS A JUGAR!
# La categoria del archivo es: culturayciencia
# El titulo es: ¡SALGAMOS A JUGAR!
# El cuerpo es: OCUPARA EL TIEMPO LIBRE PARA DESARROLLAR ACTIVIDADES AL AIRE LIBRE EN LOS BARRIOS, ESTABLECIENDO HORARIOS EN LOS CUALES LOS NIÑOS JUGARAN EN LA CALLE SIN CELULARES.
#
# El nombre de archivo es: #MontessoriParaChile
# La categoria del archivo es: interior
# El titulo es: #MontessoriParaChile
# El cuerpo es: La educación no es solo un problema del último gobierno ni tampoco de los ultimos, es un problema que se viene arrastrando mas de 100 años a nivel mundial, que a través de las generaciones ha reducido el conocimiento y la adquisición de este a un mero juego para "canjear un vale por un trabajo"(1), y a pesar de crear -o pensar crear(2)- "colegios de excelencia" con niños seleccionados para rendir, el resto->95%- se limita porque creen que no podrán nunca destacar y han perdido la curiosidad innata con que nace el ser humano(3). (1) Congreso Futuro (Febrero 2017). "¿Educacion para el siglo XXI? Claudio Naranjo en congreso Futuro 2017" (https://youtu.be/hIHaDT3RnpU)(2) ElMostradorTv(5 de Junio del 2017). "Sello Propio - José Maza, astrónomo: “De nada sirven 50 colegios de excelencia. La educación es para todos”" (http://www.elmostrador.cl/tv/archivo-tv/2017/06/05/sello-propio-jose-maza/)(3) Michio Kaku(2011). "Todos nacemos genios pero somos aplastados por la sociedad" (https://youtu.be/LelNYqVEOZQ)
#
# El nombre de archivo es: abajo lo privado y que lo público sea lo adecuado
# La categoria del archivo es: interior
# El titulo es: abajo lo privado y que lo público sea lo adecuado
# El cuerpo es: Es increíble cómo esta tan equivocado chile en esto, necesitamos educación gratuita, necesitamos trabajos dignos, como es posible que un joven que sale de un colegio privado tenga 5 veces más posibilidades de entrar a una universidad que el de colegio público, basta de la privatización abajo lo privado y que lo público sea lo adecuado
#
# El nombre de archivo es: Abriendo espacios de conversación
# La categoria del archivo es: interior
# El titulo es: Abriendo espacios de conversación
# El cuerpo es:
#
# El nombre de archivo es: Acabar con la jornada completa de clases
# La categoria del archivo es: interior
# El titulo es: Acabar con la jornada completa de clases
# El cuerpo es: Las excesivas horas de clases
#
# El nombre de archivo es: Acelerar el Metrotren de Melipilla a Santiago
# La categoria del archivo es: interior
# El titulo es: Acelerar el Metrotren de Melipilla a Santiago
# El cuerpo es: Son constantes los atochamientos vehiculares en la Autopista del Sol. Cualquier accidente en dicha autopista, genera congestión que puede durar horas. Esto produce que las personas que trabajamos en Santiago lleguen tarde a sus trabajos. Ademas, la necesidad de destinar tiempo al traslado de la casa al trabajo, tiempo que antes era para la familia, descanso y el esparcimiento, Por otra parte, existen muy pocas empresas de transporte que dan el servicio de Melipilla a Santiago, por lo que los pasajes son excesivamente caros (Puede llegar a $2000 el pasaje de ida o vuelta).
#
# El nombre de archivo es: Apoyar para obtener una educación superior digna
# La categoria del archivo es: interior
# El titulo es: Apoyar para obtener una educación superior digna
# El cuerpo es: El derecho a acceder a la educación superior sin ser catalogados por el ingreso mensual en los hogares.
#
# El nombre de archivo es: Apoyemos la educación de calidad
# La categoria del archivo es: interior
# El titulo es: Apoyemos la educación de calidad
# El cuerpo es: Que los colegios no pasen a ser Particulares
#
# El nombre de archivo es: APOYO AL CUMPLIMIENTO DE LA LEY LABORAL
# La categoria del archivo es: interior
# El titulo es: APOYO AL CUMPLIMIENTO DE LA LEY LABORAL
# El cuerpo es: NUESTRO PAÍS TIENE LA MAYORÍA DE SUS TRABAJADORES PRESTANDO SERVICIOS EN LAS PYMES Y/O MYPES, INCLUIDAS LAS MEDIANAS Y EL INCUMPLIMIENTO DE LA NORMATIVA LABORAL, RADICA PRINCIPALMENTE EN EL DESCONOCIMIENTO DE LOS PRECEPTOS LEGALES VIGENTES. LA TERMINOLOGÍA JURÍDICA COMPLICA A LAS PERSONAS QUE DEBEN APLICAR ESTOS PRECEPTOS.
#
# El nombre de archivo es: Aumentar financiamiento a la educación técnico profesional
# La categoria del archivo es: interior
# El titulo es: Aumentar financiamiento a la educación técnico profesional
# El cuerpo es: Insuficiente financiamiento para la educación técnico profesional.
#
# El nombre de archivo es: Aumentar inversión en investigación, desarrollo e innovación en la educación superior
# La categoria del archivo es: interior
# El titulo es: Aumentar inversión en investigación, desarrollo e innovación en la educación superior
# El cuerpo es: Chile hace poca investigación, desarrollo e innovación en sus universidades. La creación de conocimiento es vital para el desarrollo económico y humano de los países.
#
# El nombre de archivo es: aumento del sueldo mínimo, ajuste de horarios y educación sin sobreexplotación
# La categoria del archivo es: interior
# El titulo es: aumento del sueldo mínimo, ajuste de horarios y educación sin sobreexplotación
# El cuerpo es: -Aumento del sueldo mínimo para así no tener la necesidad de hacer horas extras y a la vez recibir un salario decente -Disminución de la jornada pedagógica de los estudiantes (30 horas a la semana)-ajuste del horario laboral (40 horas a la semana)- no más tareas para realizar en el hogar
#
# El nombre de archivo es: Avancemos en la Movilidad
# La categoria del archivo es: interior
# El titulo es: Avancemos en la Movilidad
# El cuerpo es: Existen muchos inconvenientes en la movilidad urbanas en diferentes ciudades del país. Ha llegado el momento de pensar en soluciones de largo plazo, que conecten ciudades con entornos rurales y viceversa.
#
# El nombre de archivo es: Basta de asfixia burocrática de las escuelas de Chile
# La categoria del archivo es: interior
# El titulo es: Basta de asfixia burocrática de las escuelas de Chile
# El cuerpo es: Una pesada mochila burocrática sobre las escuelas que no les permite enfocarse proveer educación de calidad.
#
# El nombre de archivo es: Beca por situacion de discapacidad
# La categoria del archivo es: interior
# El titulo es: Beca por situacion de discapacidad
# El cuerpo es: Una persona con discapacidad,además de las necesidades básicas necesita que se gasten recursos en rehabilitaciones, operaciones y/o terapias de diversos tipos lo que hace complicado el costo al acceso a una universidad y por esto urge ayuda por parte de las universidades y/o institutos técnicos.
#
# El nombre de archivo es: Brecha escolar
# La categoria del archivo es: interior
# El titulo es: Brecha escolar
# El cuerpo es:
#
# El nombre de archivo es: Calidad de la educación
# La categoria del archivo es: interior
# El titulo es: Calidad de la educación
# El cuerpo es: Actualmente en Chile no existe un buen método de aprendizaje, por lo que el alumno no aprende y el profesor se ve obligado a pasar materia que viene en la planificación de la asignatura.Este problema afecta a la mayoría de los alumnos, ya que cuando llegan a la educación superior, llegan mal preparados por culpa de la mala Calidad de la educación,por lo que tenemos algunas propuestas para solucionar este problema:-Primero que todo partir por las universidades, en donde estas deben enseñar diversos métodos de aprendizaje a a los futuros profesores ya que no todos los alumnos aprenden de igual forma.-Al hacer la evaluación docente, esta debe ser fiscalizada de una mejor manera,ya que con un método distinto se prueba de mejor forma la calidad de como enseñan los profesores-Inculcar que los padres y profesores enseñen a los alumnos a a estudiar desde pequeños.-Que los profesores hagan las clases mas recreativas ya que así los alumnos se motivan mas a aprender.
#
# El nombre de archivo es: Calles productivas con dignidad
# La categoria del archivo es: interior
# El titulo es: Calles productivas con dignidad
# El cuerpo es: Marginalidad, insalubridad, persecución, aparición de mafias, vulneración de derechos de emprendedores ambulantes.
#
# El nombre de archivo es: CAMBIO DE SISTEMA EDUCATIVO
# La categoria del archivo es: interior
# El titulo es: CAMBIO DE SISTEMA EDUCATIVO
# El cuerpo es:
#
# El nombre de archivo es: Cambios al sistema educacional
# La categoria del archivo es: interior
# El titulo es: Cambios al sistema educacional
# El cuerpo es: La perpetuación del determinismo social a causa del actual sistema educacional
#
# El nombre de archivo es: Chile unido, no segregado
# La categoria del archivo es: interior
# El titulo es: Chile unido, no segregado
# El cuerpo es: Segregación producida por el Simce
#
# El nombre de archivo es: Ciclovias V region
# La categoria del archivo es: interior
# El titulo es: Ciclovias V region
# El cuerpo es: Ingenieria de Ciudad
#
# El nombre de archivo es: colegios gratuitos de calidad y privados
# La categoria del archivo es: interior
# El titulo es: colegios gratuitos de calidad y privados
# El cuerpo es: La educación es un derecho, por ende, todo niño debe tener la oportunidad de acceder a una y de calidad. Los años de educación primaria son los años de mayor estimulación para los niños. Es necesario que todos obtengan aquella estimulación y formación. La presencia de colegios públicos con educación de calidad permitirá que aquellos que no tengan la cantidad de dinero que se requiere hoy para acceder a un colegio de calidad, puedan educarse igual que un niño que si tiene los medios. Por otro lado, la educación privada se diferenciará por incluir otros ámbitos de índole personal, tales como, religión o cultura.
#
# El nombre de archivo es: Concursos Públicos para empleos municipales, no más clientelismo
# La categoria del archivo es: interior
# El titulo es: Concursos Públicos para empleos municipales, no más clientelismo
# El cuerpo es: Clientelismo en municipios, es decir, contactos o "pitutos" que permiten acceder a un puesto de manera injusta, en perjuicio que quienes no tienen esos contactos o no quieren conseguir un empleo de esa forma, sino a través de sus méritos y/o experiencia.El problema del clientelismo o los "pitutos" nos afecta a todos, pues incluso consiguiendo los empleos se depende luego del alcalde de turno para mantenerlos, esto puede afectar negativamente a la democracia, pues entonces los resultadod de las elecciones pueden depender de qué municipio tiene más empleados contratados.
#
# El nombre de archivo es: CONDONACIÓN DE LA DEUDA EDUCATIVA Y DESMERCANTILIZACIÓN DE LA EDUCACIÓN
# La categoria del archivo es: interior
# El titulo es: CONDONACIÓN DE LA DEUDA EDUCATIVA Y DESMERCANTILIZACIÓN DE LA EDUCACIÓN
# El cuerpo es: Condonación de la Deuda Educativa y desmercantilización de la Educación: Condonación a deudores del Crédito con Aval del Estado, CORFO, Fondo Solidario, Súper-Créditos y otros créditos universitarios
#
# El nombre de archivo es: Creación de Centros de Aprendizaje Familiar para aumentar la cobertura en el nivel de sala cuna
# La categoria del archivo es: interior
# El titulo es: Creación de Centros de Aprendizaje Familiar para aumentar la cobertura en el nivel de sala cuna
# El cuerpo es: Baja cobertura en la educación inicial
#
# El nombre de archivo es: Dar mayor protección a los consumidores
# La categoria del archivo es: interior
# El titulo es: Dar mayor protección a los consumidores
# El cuerpo es: La institucionalidad de protección del consumidor ha sido fuertemente cuestionada en los últimos años debido a su incapacidad para prevenir abusos y proteger adecuadamente los derechos de los consumidores, al ser las facultades del SERNAC muy débiles, interviniendo principalmente como mediador y en demandas colectivas.En este escenario, por lo general, los órganos sectoriales velan por el funcionamiento de sus respectivos mercados, privilegiando la supervisión técnica y dejando indefenso al consumidor. Por otra parte, el SERNAC no tiene la potestad de inmiscuirse en los problemas de los consumidores en el marco de ciertos sectores regulados. Así, la manera en que el SERNAC interactúa con otros organismos públicos tiene consecuencias tanto para consumidores como para las empresas. Una buena política debe compatibilizar el buen funcionamiento de mercados técnicamente complejos con una debida protección de los consumidores.
#
# El nombre de archivo es: Defensoría de la Sociedad Civil
# La categoria del archivo es: interior
# El titulo es: Defensoría de la Sociedad Civil
# El cuerpo es: La toma de decisiones y compromisos de inversión pública y políticas públicas que afectan a las personas a lo largo de país son tomadas de forma centralizada y no abarcan la realidad de las problemáticas territoriales.
#
# El nombre de archivo es: Derecho a la seguridad y protección a la vida de los trabajadores
# La categoria del archivo es: interior
# El titulo es: Derecho a la seguridad y protección a la vida de los trabajadores
# El cuerpo es: Accidentes del trabajo y daños psicosociales del mundo laboral
#
# El nombre de archivo es: Derechos colectivos e individuales de los trabajadores
# La categoria del archivo es: interior
# El titulo es: Derechos colectivos e individuales de los trabajadores
# El cuerpo es: Resulta fundamental profundizar los derechos en el mundo laboral, en línea con los tratados internacionales ratificados por nuestro país. Uno de los debates pendientes en la reforma labora fue no abordar la plena libertad sindical, garantizando el derecho a negociación ramal o sectorial. A lo anterior se suman la modificación de instrumentos, como el Estatuto Administrativo para trabajadores(as) del Estado; la promulgación de un Estatuto del Trabajador Agrícola de Temporada; el término al subcontrato impropio; la instauración de la indemnización para los trabajadores por obra o faena; la implementación de la Recomendación N°204 de OIT sobre Economía Informal , que reconoce a dirigentes del sector; el pleno reconocimiento del fuero sindical para los trabajadores del sector público, privado e informal, y para dirigentes de todos los niveles de organizaciones sindicales superiores como la CUT.
#
# El nombre de archivo es: Derechos para las Escuelas
# La categoria del archivo es: interior
# El titulo es: Derechos para las Escuelas
# El cuerpo es: Poco financiamiento del Gobierno en recursos que contribuyan a una educación integral en las escuelas.
#
# El nombre de archivo es: Descentralización
# La categoria del archivo es: interior
# El titulo es: Descentralización
# El cuerpo es: El actual sistema político, regido por la actual Constitución Chilena, es centralizado, y profundiza inequidad territorial para regiones.La mayoría de la estructura politica-social. es enfocado en Región Metropolitana, relevando a un segundo plano, comunes y regiones.´Mi propuesta social-ciudadana consiste en siguientes items:1) Presupuesto Regional-comunal: Recurso económico-social, destinado a desarrollo social, cultural, laboral, educacional y medioambiental.2) Protección Medio-ambiental: Marco normativo-juridico, que estipule: a) Defensa y protección de medio-ambiente. b) Difusión, promoción y fomentación de espacios con áreas verdes. c) Equidad e integridad regional y comunal. 3) Promulgación de atribuciones jurídicas municipales y participación ciudadana: 4) Sanción jurídica a contaminación. 5) Erradicación de campamentos e inequidad en regiones.
#
# El nombre de archivo es: Descentralización Fiscal-Económica Responsable
# La categoria del archivo es: interior
# El titulo es: Descentralización Fiscal-Económica Responsable
# El cuerpo es: Falta de Descentralización fiscal-económica
#
# El nombre de archivo es: Descentralización parq Valparaíso y otras regiones
# La categoria del archivo es: interior
# El titulo es: Descentralización parq Valparaíso y otras regiones
# El cuerpo es: Ausencia de descentralización en Valparaíso y regiones.
#
# El nombre de archivo es: Descentralización y desarrollo de país mediante Impuestos Diferenciados
# La categoria del archivo es: interior
# El titulo es: Descentralización y desarrollo de país mediante Impuestos Diferenciados
# El cuerpo es: Alta centralización y escaso desarrollo de regiones. Regiones con diversos potenciales por desarrollar.Existe una alta concentración de la población en la región metropolitana, esto debido a mayores oportunidades de trabajo, alternativas de salud, educación y entretenimiento. Las regiones no tienen la oportunidad de atraer gente porque tienen pocas oportunidades de trabajo y pocas alternativas de salud, educación y entretenimiento.La propuesta es que para lograr la descentralización, la distribución de impuestos sea porcentual a partir de la concentración de personas por metro cuadrado, por región o mejor aún por comuna y que el porcentaje se calcule todos los años.
#
# El nombre de archivo es: Descentralizar Chile en corto plazo
# La categoria del archivo es: interior
# El titulo es: Descentralizar Chile en corto plazo
# El cuerpo es: Descentralizar el país de manera rápida para así disminuir los altos costos de propiedades en Santiago, el trafico, mejorar la economía de forma global, mejorar las regiones y sacarle partido a las mismas.
#
# El nombre de archivo es: Descentralizar partiendo por el estado
# La categoria del archivo es: interior
# El titulo es: Descentralizar partiendo por el estado
# El cuerpo es:
#
# El nombre de archivo es: Dictadura
# La categoria del archivo es: interior
# El titulo es: Dictadura
# El cuerpo es:
#
# El nombre de archivo es: Directivos de calidad y con más atribuciones para las escuelas de Chile
# La categoria del archivo es: interior
# El titulo es: Directivos de calidad y con más atribuciones para las escuelas de Chile
# El cuerpo es: Si bien hay muchos directores y directoras ejemplares, de forma general, hoy no estamos asegurando que los equipos directivos de los establecimientos educacionales sean de la mejor calidad.
#
# El nombre de archivo es: Diseño e implementación de un nuevo sistema integrado de transporte publico para las comunas de S
# La categoria del archivo es: interior
# El titulo es: Diseño e implementación de un nuevo sistema integrado de transporte publico para las comunas de S
# El cuerpo es: El gran problema de Talca es la movilidad ya que el transporte publico no cubre la demanda cuantitatuva ni cualitativa de la comunidad por lo que muchos pasajeros no alcanzan a tomar su transporte para trabajar o estudiar y esto es reflejo de la falta de servicios de locomocion colectiva, sumado a esto tenemos el problema de la congestión vehucular en las principales avenidas lo cual retrasa bastante la llegada a destino de los usuarios lo que refleja la falta de vías y corredores exclusivos para buses y locomoción colectiva. Considerando además la conurbación con Maule, este problema afecta más a la locomocion colectiva de Talca ya que los usuarios de Maule viajan a Talca a estudiar y trabajar. Tampoco existe interés en crear un sistema de transporte público integrado con un tren de cercanía hacia Maule y San Javier, que sí daría una solución real a este problema
#
# El nombre de archivo es: Economía solidaria
# La categoria del archivo es: interior
# El titulo es: Economía solidaria
# El cuerpo es: Hay demasiada desigualdad económica debido a los privilegios económicos de las personas de cargos políticos
#
# El nombre de archivo es: Educación Ambiental en la Escuelas
# La categoria del archivo es: interior
# El titulo es: Educación Ambiental en la Escuelas
# El cuerpo es: Inexistencia de una política pública que fomente e implemente programas en educación sobre la importancia y las formas de cuidado del medioambiente.
#
# El nombre de archivo es: Educación civica de calidad
# La categoria del archivo es: interior
# El titulo es: Educación civica de calidad
# El cuerpo es: Falta de educación con respecto de la sociedad en la poblacion chilena
#
# El nombre de archivo es: Educación colaborativa y más práctica
# La categoria del archivo es: interior
# El titulo es: Educación colaborativa y más práctica
# El cuerpo es: La deficiencia en el trabajo práctico colaborativo en la educación así como también la enseñanza de hábitos de comportamiento social como es colaborar con la limpieza, la amabilidad, etc.
#
# El nombre de archivo es: Educación especializada
# La categoria del archivo es: interior
# El titulo es: Educación especializada
# El cuerpo es: En algunos colegios cómo el Montessori utilizan métodos dinamicos para enseñar , pero no existen en Chile colegios o escuelas para darle enfoque a una especialidad. Por ejemplo: una escuela de teatro.
#
# El nombre de archivo es: Educación gratuita y con docentes que aseguren la calidad de contenidos en la educación
# La categoria del archivo es: interior
# El titulo es: Educación gratuita y con docentes que aseguren la calidad de contenidos en la educación
# El cuerpo es: -Colegios, liceos, universidades e institutos gratuitos y de calidad.-Cada institución debe velar que sus docentes manejen el contenido que se debe ver durante el año escolar, así la enseñanza es de calidad y significativa para los estudiantes. -Aumentar el sueldo de los profesores.-Los profesores tengan las herramientas necesarias para mejorar el contenido a través de la creatividad. -Que todo colegio o escuela sea municipal o particular implemente los mismos contenidos. -Los profesores les enseñen a todos sus estudiantes los mismos contenidos y confirmen que todos sus estudiantes aprendieron, siendo inclusivos.
#
# El nombre de archivo es: Educación humanística y con acceso equitativo para Chile
# La categoria del archivo es: interior
# El titulo es: Educación humanística y con acceso equitativo para Chile
# El cuerpo es: Sistema educatico segregacionista y exclusivista.
#
# El nombre de archivo es: Educación para la Nueva Economía
# La categoria del archivo es: interior
# El titulo es: Educación para la Nueva Economía
# El cuerpo es: Frustración patológica generada por el sentido del éxito que hoy enseña y transmite nuestro modelo educativo
#
# El nombre de archivo es: Educaion gratuita trabajo estable
# La categoria del archivo es: interior
# El titulo es: Educaion gratuita trabajo estable
# El cuerpo es: Ya kue por los elecciones precidelciales se estan tomando drasticamente ideas concretas y debates exagerdos por la toma y mando de la presidenta se perdio el prestigio que abundaba en ellla pero oy en dia la gratuidad debe seguir para tener un trabajo estable
#
# El nombre de archivo es: Educar a todos los niños y niñas de Chile
# La categoria del archivo es: interior
# El titulo es: Educar a todos los niños y niñas de Chile
# El cuerpo es: Problema: que los niños y niñas no logran recibir la misma educación ni sacar sus estudios hacia adelante por que existe mala educación con profesores poco profesionalizados. Causas: Falta de recursos, oportunidades y clasismo muy fuerte en chile que afecta el uso de materiales que afecta la educación de los niños.Efectos:Los niños no logran salir adelante, aumenta la ignorancia, delincuencia, pobreza y falta de oportunidades laboralesSolución: 1. Que la educación sea igual para todos para que todos puedan recibir la misma educación2. Más recursos y Becas para todos3. Mejor calidad de colegio con profesores más capacitados que comprendan a sus alumnos.
#
# El nombre de archivo es: El futuro de $hile
# La categoria del archivo es: interior
# El titulo es: El futuro de $hile
# El cuerpo es: Disminuir las horas laborales de los docentes frente a aula y de la jornada escolar, con el propósito de tener más tiempo libre y de recreación, ya que las horas extra-programática no se respetan en todos los establecimientos.
#
# El nombre de archivo es: EL TRABAJO COMO FUENTE DE EDUCACIÓN
# La categoria del archivo es: interior
# El titulo es: EL TRABAJO COMO FUENTE DE EDUCACIÓN
# El cuerpo es: HOMBRES Y MUJERES DEBERIAN GANAR LOS MISMOS SUELDOS PARA ASI MEJORAR LA EDUCACIÓN DE SUS HIJOS.
#
# El nombre de archivo es: eliminacion de monopolios y la fomentacion de la pequeña y mediana industria
# La categoria del archivo es: interior
# El titulo es: eliminacion de monopolios y la fomentacion de la pequeña y mediana industria
# El cuerpo es: Fomentar la producción privada a pequeña y mediana escala pero a su vez el control del estado de los grandes mercados claves para facilitar el acceso de los emprendedores, de los trabajadores y con las ganancias percapita percibidas por el estado de estos macro-mercados asegurar derechos fundamentales como salud , educacion, vivienda entre otros.
#
# El nombre de archivo es: Eliminación del sistema económico nominado Cae
# La categoria del archivo es: interior
# El titulo es: Eliminación del sistema económico nominado Cae
# El cuerpo es: Eliminar el sistema Cae para estudiantes.
#
# El nombre de archivo es: Eliminar los beneficios tributarios que solo benefician al gran empresariado monopolista
# La categoria del archivo es: interior
# El titulo es: Eliminar los beneficios tributarios que solo benefician al gran empresariado monopolista
# El cuerpo es: Las empresas en Chile son de las mas multimillonarias del mundo junto con paises que tambien son paraisos fiscales o tributarios. propuesta es eliminar los beneficios tributarios que por lo general son muy usados por grandes empresas que centralizan la mayor producción y que gracias a siertos mecanimos postergan o recuperan los pagos de los impuestos como la exención del impuesto del que da cuenta la Ley N° 16.271 la llamada ley de donaciones, donde en palabra simples las empresas que donen a caridad evaden impuestos siendo que estas macroempresaas o empresas monopolicas solo dan el 30% de lo que recibe por ejemplo la teleton. ,
#
# El nombre de archivo es: Explotacion laboral de los inmigrantes
# La categoria del archivo es: interior
# El titulo es: Explotacion laboral de los inmigrantes
# El cuerpo es: Crear una ley donde los inmigrantes tengan los mismos derechos en relación a su trabajo ( condiciones laborales, remuneraciones, horas de descanso, etc).
#
# El nombre de archivo es: Financiamiento estudiantil justo, responsable y equitativo
# La categoria del archivo es: interior
# El titulo es: Financiamiento estudiantil justo, responsable y equitativo
# El cuerpo es: Desigual apoyo fiscal al acceso a la educación superior de todos los estudiantes
#
# El nombre de archivo es: Financiamiento universitario con devolución
# La categoria del archivo es: interior
# El titulo es: Financiamiento universitario con devolución
# El cuerpo es: Financiamiento universitario con devolución
#
# El nombre de archivo es: Flexibilizar los horarios de los establecimientos de educación inicial
# La categoria del archivo es: interior
# El titulo es: Flexibilizar los horarios de los establecimientos de educación inicial
# El cuerpo es: Muchas familias se rehúsan a llevar a sus niños o niñas a salas cuna y jardines infantiles, porque cuestionan su calidad o porque no los encuentran en lugares accesibles o porque los horarios son incompatibles con sus jornadas laborales oporque prefieren cuidarlos en casa.
#
# El nombre de archivo es: Formación ciudadana para adultos
# La categoria del archivo es: interior
# El titulo es: Formación ciudadana para adultos
# El cuerpo es: Discusión en torno a formación ciudadana está dirigida predominantemente al segmento escolar, sin considerar que es una necesidad para todas las edades ni aprovechando la experiencia de los mayores.
#
# El nombre de archivo es: Formación para el trabajo y la vida
# La categoria del archivo es: interior
# El titulo es: Formación para el trabajo y la vida
# El cuerpo es: Educación vista como un bien de consumo y no como un derecho social universal en todos sus niveles educativos.
#
# El nombre de archivo es: Fortalecer el rol y las capacidades de los directores y sus equipos
# La categoria del archivo es: interior
# El titulo es: Fortalecer el rol y las capacidades de los directores y sus equipos
# El cuerpo es: • Falta de calidad en todos los sectores socioeconómicos. • Falta de calidad es más dura en sectores desfavorecidos. Tres de cada cuatro estudiantes chilenos que viven en pobreza tienen bajo desempeño en la prueba PISA.El desafío no surge en su adolescencia. A los tres años, los niños del grupo socioeconómico más bajo en Chile no han desarrollado el lenguaje necesario para comprender el mundo, y el número de palabras que manejan ya es significativamente menor en relación a un niño nacido en el 20% más rico de la población. • No sabemos aplicar en nuestra vida diaria lo que nos enseñan. El modelo educativo está descontextualizado en el qué y cómo se enseña.• Los directores no pueden/quieren/saben empoderar a sus profesores y comunidad educativa.• Estudiantes con necesidades humanas básicas no resueltas: Los estudiantes que viven en contextos de pobreza y vulnerabilidad no tienen resueltas diversas necesidades básicas. Estas urgencias exigen respuestas rápidas que permitan prevenirlas y abordarlas.
#
# El nombre de archivo es: Funciones básicas de la programación
# La categoria del archivo es: interior
# El titulo es: Funciones básicas de la programación
# El cuerpo es: La falta de programadores
#
# El nombre de archivo es: gratuidad para las universidades y colegios
# La categoria del archivo es: interior
# El titulo es: gratuidad para las universidades y colegios
# El cuerpo es: no me gustaria que los colegios de chile tengan que pagar una mensualidad, no todos tienen los recursos para pagar una gran cantidad de dinero por estudiar, la educacion es una parte fundamental para los niños,nosotros somos el futuro de chile y creo que todos tenemos derecho ah estudiar sin tener que pagar...
#
# El nombre de archivo es: Horario acotado de media jornada para los alumnos
# La categoria del archivo es: interior
# El titulo es: Horario acotado de media jornada para los alumnos
# El cuerpo es: -Un nuevo horario hasta media jornada para todos los estudiante, ya que esto permite un mejora de estudio, mejores rendimientos académicos y menos estrés.
#
# El nombre de archivo es: Igualdad de rentas
# La categoria del archivo es: interior
# El titulo es: Igualdad de rentas
# El cuerpo es: Igualdad de salarios entre hombres y mujeres
#
# El nombre de archivo es: Igualdad de Sueldos
# La categoria del archivo es: interior
# El titulo es: Igualdad de Sueldos
# El cuerpo es: Que las mujeres tengas igualdades laborales, obteniendo mejores sueldo y equitativos con los de los hombres.
#
# El nombre de archivo es: Implementar bachilleres gratuitos para todos, parte mas barata de la formación universitaria
# La categoria del archivo es: interior
# El titulo es: Implementar bachilleres gratuitos para todos, parte mas barata de la formación universitaria
# El cuerpo es: Financiamiento de la educación
#
# El nombre de archivo es: Impuesto territorial para empresas forestales
# La categoria del archivo es: interior
# El titulo es: Impuesto territorial para empresas forestales
# El cuerpo es: A pesar de representar a uno de los sectores más relevantes de la economía nacional, los territorios en los que la empresa forestal se encuentra asentada representan en gran medida parte de los sectores más pobres del país. Dentro de la multiplicidad de causas que subyacen al mantenimiento y expansión de la pobreza en las regiones y comunas con alto índice de actividad forestal, existe una directamente vinculada con los poderes y atribuciones del Estado y el marco normativo que regula su actividad. La ley 17.235 establece el denominado “impuesto territorial” que determina que el 100% de lo recaudado mediante este medio debe ser destinado a los fondos municipales, A pesar de esto CONAF reconoce no haber cobrado jamás este impuesto lo que genera una situación en la que la actividad extractiva solo percibe ganancias a costa del agotamiento de recursos naturales de los territorios.
#
# El nombre de archivo es: Infraestructura para una Movilidad Sostenible
# La categoria del archivo es: interior
# El titulo es: Infraestructura para una Movilidad Sostenible
# ...
#
# El nombre de archivo es: Saquen la regla de los piercing
# La categoria del archivo es: social
# El titulo es: Saquen la regla de los piercing
# El cuerpo es: Que saquen del reglamento interno de los colegios , de que no se pude ocupar piercing ,teñír el pelo etcEso no nos hace distintos , que nos dejen ser nosotros
#
# El nombre de archivo es: Sename
# La categoria del archivo es: social
# El titulo es: Sename
# El cuerpo es: -Concretar la división del servicio del SENAME. -Aumentar los fondos para poder concretar la contrata de más personal. -Que se contraten profesionales especializados en el área.
#
# El nombre de archivo es: Sensibilizar sobre la importancia de la transparencia e incentivar a las organizaciones de la soc
# La categoria del archivo es: social
# El titulo es: Sensibilizar sobre la importancia de la transparencia e incentivar a las organizaciones de la soc
# El cuerpo es: La transparencia de las OSC no es una prioridad, lo que pone en riesgo la fe pública y la confianza depositada en ellas.
#
# El nombre de archivo es: Seremos [email protected]
# La categoria del archivo es: social
# El titulo es: Seremos [email protected]
# El cuerpo es: Participación en los menores de edad
#
# El nombre de archivo es: Si gana el afiliado, gana la AFP. Si pierde al afiliado, pierde la AFP también
# La categoria del archivo es: social
# El titulo es: Si gana el afiliado, gana la AFP. Si pierde al afiliado, pierde la AFP también
# El cuerpo es: En Chile, para la mayoría de las personas que se jubilan, las pensiones no les alcanzan para cubrir sus necesidades con dignidad.
#
# El nombre de archivo es: Simplificar las leyes de donaciones para diversificar el número de donantes y receptores
# La categoria del archivo es: social
# El titulo es: Simplificar las leyes de donaciones para diversificar el número de donantes y receptores
# El cuerpo es: Para la mayoría de las OSC, el financiamiento es una tarea desgastante, que exige dedicar una parte importante de su tiempo y recursos a la postulación, captación y renovación de fondos que son de corto plazo, y a estar en permanente competencia con otras organizaciones, lejos de un modelo que incentive la colaboración.
#
# El nombre de archivo es: Sin rejas
# La categoria del archivo es: social
# El titulo es: Sin rejas
# El cuerpo es: Es una crueldad y viola los derechos del niño ponerlos entre rejas.
#
# El nombre de archivo es: Sistema de reparto equitativo para adultos mayores
# La categoria del archivo es: social
# El titulo es: Sistema de reparto equitativo para adultos mayores
# El cuerpo es: Un sistema solidario y de reparto con pensiones e quitativas y justas para jubilados,adultos mayores y trabajadores.
#
# El nombre de archivo es: Sistema Nacional de Apoyo y Cuidado
# La categoria del archivo es: social
# El titulo es: Sistema Nacional de Apoyo y Cuidado
# El cuerpo es: En Chile no existe una mirada intersectorial y longitudinal del fenómeno de las personas con dependencia, ni apoyo en su contexto ni tampoco de sus cuidadores/as. El análisis y datos siempre han sido recogidos desde el diagnóstico o condición específica de ciertos subgrupos dentro de este gran colectivo. El 59,6% de las personas con discapacidad y el 14,4% de los adultos mayores, se encuentran en situación de dependencia y para ambas poblaciones en cerca de un 90% sus cuidadores son familiares y de estos cuidadores, un 80% son mujeres.Las consecuencias de no contar con servicios adecuados, oportunos y de calidad pueden ser de alto impacto en el empobrecimiento de las personas en situación de dependencia y sus familias, generando un deterioro en todas dimensiones del bienestar, y también la muerte. Por otro lado, el no reconocimiento del trabajo de apoyo y cuidado que hoy realizan un porcentaje importante de mujeres, invisibiliza su necesidad de inclusión laboral.
#
# El nombre de archivo es: Soluciones diferentes de jubilación en Chile
# La categoria del archivo es: social
# El titulo es: Soluciones diferentes de jubilación en Chile
# El cuerpo es: Baja pensiones de los chilenos en la AFPFalta de educación de inversión de los ciudadanos
#
# El nombre de archivo es: Solución habitacional adecuada para familias que residen en asentamientos precarios. Microcampame
# La categoria del archivo es: social
# El titulo es: Solución habitacional adecuada para familias que residen en asentamientos precarios. Microcampame
# El cuerpo es: Poco acceso a una vivienda propia
#
# El nombre de archivo es: Talleres para fomentar la comprensión de parte de los padres hacia los hijos adolescentes
# La categoria del archivo es: social
# El titulo es: Talleres para fomentar la comprensión de parte de los padres hacia los hijos adolescentes
# El cuerpo es: Fomentar el trato cariñoso entre padres e hijos adolescentes mediante talleres obligatorios que se realicen en el colegio y a los cuales puedan asistir juntos, para así fomentar la unidad de la familia y el bienestar del adolescente, informándoles a los padres por ejemplo que cosas son normales durante este periodo y cuales no lo son para que ellos comprendan todos los cambios que ocurren al ser un adolescente, y enseñándoles a los hijos a no alejarse de sus padres, a exigir sus derechos y a tomar buenas decisiones.
#
# El nombre de archivo es: TERMINAR CON ABUSOS DE CASAS COMERCIALES Y ENTIDADES BANCARIAS
# La categoria del archivo es: social
# El titulo es: TERMINAR CON ABUSOS DE CASAS COMERCIALES Y ENTIDADES BANCARIAS
# El cuerpo es: Terminar con abusos comerciales que solo afectas a las personas mas pobres
#
# El nombre de archivo es: Titulo
# La categoria del archivo es: social
# El titulo es: Titulo
# El cuerpo es:
#
# El nombre de archivo es: todos o ninguno
# La categoria del archivo es: social
# El titulo es: todos o ninguno
# El cuerpo es: Clases de integración en los colegios donde se aprenda sobre inmigración e identidad de genero y condición sexual de las personas.
#
# El nombre de archivo es: Tolerancia 0 a la violencia de género en los colegio
# La categoria del archivo es: social
# El titulo es: Tolerancia 0 a la violencia de género en los colegio
# El cuerpo es: Proponemos que se elemine cualquier tipo de discriminación y violencia de género en los colegios por ejemplo que se expanda la idea de no escuchar reggetón en actividades del colegio ya que estas canciones promueven la violencia especialmente hacia las mujeres, entonces que los colegios sean lugares donde se promueva la cultura de la integración y la igualdad.
#
# El nombre de archivo es: trabajo para los inmigrantes
# La categoria del archivo es: social
# El titulo es: trabajo para los inmigrantes
# El cuerpo es: mejorar el pensamiento de los chilenos(todos somos iguales)
#
# El nombre de archivo es: un hogar para cada familia
# La categoria del archivo es: social
# El titulo es: un hogar para cada familia
# El cuerpo es: Que ninguna familia tenga que vivir en la calle o en campamentos, que el Estado entregue hogares para todas las familias más necesitadas y que los niños que no tienen padres puedan ser adoptados más rápidamente, ademas que los orfanatos tengan buena calidad y ningún niño pase necesidades económicas y de amor.
#
# El nombre de archivo es: Un ministerio del adulto mayor nos convoca a todas y todos
# La categoria del archivo es: social
# El titulo es: Un ministerio del adulto mayor nos convoca a todas y todos
# El cuerpo es: Discriminación en todos los ámbitos, pero en especial en contra de los adultos mayores.
#
# El nombre de archivo es: Un pais donde se pueda estar tranquilo sin discriminación
# La categoria del archivo es: social
# El titulo es: Un pais donde se pueda estar tranquilo sin discriminación
# El cuerpo es: Poder pasear libremente en el pais sin discriminación o sin que la gente este pendiente de la otra, que sea un pais mas libre y que la gente se abra de mente
#
# El nombre de archivo es: Un país amoroso y protector de sus niños y jóvenes
# La categoria del archivo es: social
# El titulo es: Un país amoroso y protector de sus niños y jóvenes
# El cuerpo es: La situación de los niños y jóvenes en nuestro país en dramática. El Estado de Chile, gobierno tras gobierno, ha sido negligente en el cumplimiento de su deber de cuidar y proteger a los niños más vulnerables de nuestro país. Ni el Ministerio de Justicia, ni el Ministerio de Educación, ni el Ministerio de Salud, han sabido cumplir con sus obligaciones de dar y garantizar justicia, educación y salud a los niños y jóvenes más vulnerables.En los últimos años, más de 1.300 niños y jóvenes han muerto en el SENAME (al menos, esa es la cifra oficial). No se sabe cuántos más han visto atropellados sus derechos humanos más fundamentales o, incluso, han sido derechamente abusados, física o psicológicamente.Esto no puede ni debe seguir así, porque la fortaleza de una sociedad se mide por la fuerza de su eslabón más débil: en este caso, nuestros niños y jóvenes.
#
# El nombre de archivo es: Una mejor via publica para todos
# La categoria del archivo es: social
# El titulo es: Una mejor via publica para todos
# El cuerpo es: Infraestructura vial y publica
#
# El nombre de archivo es: unión civil
# La categoria del archivo es: social
# El titulo es: unión civil
# El cuerpo es: que todas las personas homosexuales tengan derecho a amar con libertad a quien quiera amae
#
# El nombre de archivo es: Urbanización con energía solar
# La categoria del archivo es: social
# El titulo es: Urbanización con energía solar
# El cuerpo es: Falta de integración de recursos naturales como propuesta urbana
#
# El nombre de archivo es: URGENTE DESINTERNACIÓN DE NIÑOS DE ENTRE 0 Y 6 AÑOS DE LAS RESIDENCIAS DE PROTECCIÓN
# La categoria del archivo es: social
# El titulo es: URGENTE DESINTERNACIÓN DE NIÑOS DE ENTRE 0 Y 6 AÑOS DE LAS RESIDENCIAS DE PROTECCIÓN
# El cuerpo es: Terminar con la internación de niños menores de 6 años e iniciar un proceso de desinternación de niños de entre 6 y 12 años.
#
# El nombre de archivo es: Uso amigable del Espacio Público
# La categoria del archivo es: social
# El titulo es: Uso amigable del Espacio Público
# El cuerpo es: Mal uso del espacio público comunitario (drogadicción, microtráfico, delincuencia, etc)
#
# El nombre de archivo es: Veterinarias publicas
# La categoria del archivo es: social
# El titulo es: Veterinarias publicas
# El cuerpo es: Ayuda a los animales callejeros y maltratados
#
# El nombre de archivo es: Vida digna
# La categoria del archivo es: social
# El titulo es: Vida digna
# El cuerpo es: Hay un gran aumento de hacinamientos en Chile y son muy precarias las condiciones
#
# El nombre de archivo es: VIDA SEXTA DÉCADA SIGLO XXI
# La categoria del archivo es: social
# El titulo es: VIDA SEXTA DÉCADA SIGLO XXI
# El cuerpo es: El problema que se quiere solucionar es:El gran tema país: ¿CÓMO SE PREPARA CHILE PARA ENFRENTAR EL ACELERADO ENVEJECIMIENTO DE LA POBLACIÓN CON EXPECTATIVAS DE VIDA + - 100 AÑOS?
#
# El nombre de archivo es: Visa por Motivos Laborales
# La categoria del archivo es: social
# El titulo es: Visa por Motivos Laborales
# El cuerpo es: Irregularidad migratoria para personas en búsqueda de trabajo.
#
# El nombre de archivo es: Visibilización de la mujer en el arte
# La categoria del archivo es: social
# El titulo es: Visibilización de la mujer en el arte
# El cuerpo es: Invisibilización del rol de la mujer en el arte
#
# El nombre de archivo es: Visibilizar y reconocer el rol de las organizaciones de la sociedad civil
# La categoria del archivo es: social
# El titulo es: Visibilizar y reconocer el rol de las organizaciones de la sociedad civil
# El cuerpo es: Las OSC enfrentan dificultades de base para incidir de forma efectiva en las políticas públicas, locales o sectoriales, encontrando que los espacios formales de participación no están concebidos para asegurar una incidencia relevante en las decisiones políticas.
#
# El nombre de archivo es: Vivienda Digna por un futuro mejor (Dirigentes de Campamentos de la Región Metropolitana)
# La categoria del archivo es: social
# El titulo es: Vivienda Digna por un futuro mejor (Dirigentes de Campamentos de la Región Metropolitana)
# El cuerpo es: Chile cuenta con más de 40.000 familias viviendo en campamentos.
#
# El nombre de archivo es: Vivienda Social Digna. Entregar los recursos y herramientas necesarias para lograr proyectos de
# La categoria del archivo es: social
# El titulo es: Vivienda Social Digna. Entregar los recursos y herramientas necesarias para lograr proyectos de
# El cuerpo es: Viviendas sociales dignas y acordes a las necesidades de cada familia
#
# El nombre de archivo es: ¡MENOS TRABAJO, MAS TIEMPO CON LA FAMILIA!
# La categoria del archivo es: social
# El titulo es: ¡MENOS TRABAJO, MAS TIEMPO CON LA FAMILIA!
# El cuerpo es: MARCHAR PARA EXIGIR UNA LEY PARA QUE PADRES Y ABUELOS TRABAJEN MENOS HORAS Y TENGAN TIEMPO LIBRE PARA COMPARTIR EN FAMILIA. QUE LOS SUELDOS SEAN MAS ALTOS, POR MENOS HORAS DE TRABAJO.
#
# El nombre de archivo es: “HACER COSAS BUENAS” SIN DISCRIMINACIÓN PARA TODOS Y TODAS
# La categoria del archivo es: social
# El titulo es: “HACER COSAS BUENAS” SIN DISCRIMINACIÓN PARA TODOS Y TODAS
# El cuerpo es: Que el presidente se preocupe de incorporar en sus planes y políticas de gobierno políticas sin discriminación de sexo, raza, religión u otra categoría, integrando universalmente a todas las personas sobre todo a los más necesitados en pro de la “paz mundial” destacando entre los principios fundamentales de estos programas la libertad de expresión, libertad de creencia, raza y nacionalidad.
#
# El nombre de archivo es: “PROTECCIÓN A LA FAMILIA Y EL MEDIO AMBIENTE”
# La categoria del archivo es: social
# El titulo es: “PROTECCIÓN A LA FAMILIA Y EL MEDIO AMBIENTE”
# El cuerpo es: Es importante que el presidente electo cree una Ley para la protección y cuidado del medio ambiente, mejorando los entornos comunitarios, seguridad ciudadana, pero además potenciar el desarrollo del tiempo en familia, ajustando las jornadas educativas de los niños, niñas y adolescentes.
#             category                                              title  \
# 0    culturayciencia              Acceso a la cultura y el conocimiento
# 1    culturayciencia                          Acercando a la Biblioteca
# 2    culturayciencia                                      Arte, cultura
# 3    culturayciencia  Cambio de paradigma por parte del estado en la...
# 4    culturayciencia                        CAMBIO DE SISTEMA EDUCATIVO
# ..               ...                                                ...
# 693           social  Vivienda Digna por un futuro mejor (Dirigentes...
# 694           social  Vivienda Social Digna. Entregar los recursos y...
# 695           social         ¡MENOS TRABAJO, MAS TIEMPO CON LA FAMILIA!
# 696           social  “HACER COSAS BUENAS” SIN DISCRIMINACIÓN PARA T...
# 697           social      “PROTECCIÓN A LA FAMILIA Y EL MEDIO AMBIENTE”
#
#                                                content  category_id
# 0    El sistema de derechos de autor se encuentra d...            0
# 1    Las bibliotecas publicas no son usadas por los...            0
# 2                      Valorización del arte en chile.            0
# 3    Contaminación de las ciudades y altos costos d...            0
# 4                                                                 0
# ..                                                 ...          ...
# 693  Chile cuenta con más de 40.000 familias vivien...            5
# 694  Viviendas sociales dignas y acordes a las nece...            5
# 695  MARCHAR PARA EXIGIR UNA LEY PARA QUE PADRES Y ...            5
# 696  Que el presidente se preocupe de incorporar en...            5
# 697  Es importante que el presidente electo cree un...            5
#
# [698 rows x 4 columns]

# %%
#En este bloque se guardan ordenados los valores por categoria y su id
category_id_df = df[['category', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'category']].values)

# %%
#En este bloque se imprime por pantalla una grafica de cuantos archivos hay por cada categoria
fig = plt.figure(figsize=(6,4))
df.groupby('category').content.count().plot.bar(ylim=0)
plt.show()
#Forma mas resumida de mostrar el grafico
#df.groupby('category').filename.count().plot.bar(ylim=0)

# %%
#En este bloque se crea la matriz TF-IDF con los stopwords de español
stop_es=stopwords.words('spanish')
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=3, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words=stop_es)
features = tfidf.fit_transform(df.content).toarray()
labels = df.category_id
features.shape
# Out:
# (698, 1498)

# %%
#En este bloque se imprime los unigramas y bigramas mas representativos de cada clase. Hay un fallo en esta libreria en el
#caso de ser solo dos clases.
N = 3
for category, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(category))
  print("  . Unigramas mas representativos:\n. {}".format('\n. '.join(unigrams[-N:])))
  print("  . Bigramas mas representativos:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# # 'culturayciencia':
#   . Unigramas mas representativos:
# . deportistas
# . canchas
# . deporte
#   . Bigramas mas representativos:
# . aire libre
# . tiempo libre
# . falta recursos
# # 'interior':
#   . Unigramas mas representativos:
# . colegios
# . profesores
# . educación
#   . Bigramas mas representativos:
# . educación calidad
# . educación gratuita
# . calidad educación
# # 'medioambiente':
#   . Unigramas mas representativos:
# . reciclaje
# . contaminación
# . basura
#   . Bigramas mas representativos:
# . mismos ciudadanos
# . plazas parques
# . medio ambiente
# # 'politica':
#   . Unigramas mas representativos:
# . antisemitismo
# . políticos
# . corrupción
#   . Bigramas mas representativos:
# . querellas corrupción
# . recursos públicos
# . incitación odio
# # 'sanidad':
#   . Unigramas mas representativos:
# . medicamentos
# . hospitales
# . salud
#   . Bigramas mas representativos:
# . alto costo
# . servicio salud
# . salud pública
# # 'social':
#   . Unigramas mas representativos:
# . basura
# . discriminación
# . sename
#   . Bigramas mas representativos:
# . derecho vivienda
# . personas discapacidad
# . personas mayores

# %%
#En este bloque se imprime una grafica punteada de un ejemplo del 30% de los datos de la matriz tf-idf
SAMPLE_SIZE = int(len(features) * 0.2)
np.random.seed(0)
indices = np.random.choice(range(len(features)), size=SAMPLE_SIZE, replace=False)
projected_features = TSNE(n_components=2, random_state=0).fit_transform(features[indices])
colors = ['pink', 'green', 'midnightblue', 'orange', 'darkgrey', 'yellow']
for category, category_id in sorted(category_to_id.items()):
    points = projected_features[(labels[indices] == category_id).values]
    plt.scatter(points[:, 0], points[:, 1], s=30, c=colors[category_id], label=category)
plt.title("vector de características tf-idf para cada artículo, proyectado en 2 dimensiones.",
          fontdict=dict(fontsize=15))
plt.legend()

# %%
#En este bloque podemos buscar palabras que contengan los titulos del dataframe
df[df.title.str.contains('mayores')]
# Out:
#     category                                              title  \
# 553   social  Mejorar la calidad de vida de las personas may...
# 598   social                    Pensiones a los adultos mayores
# 668   social  Sistema de reparto equitativo para adultos may...
#
#                                                content  category_id
# 553  as precariedades del Adulto Mayor que se tradu...            5
# 598  Todos sabemos que hoy en día los adultos mayor...            5
# 668  Un sistema solidario y de reparto con pensione...            5

# %%
#En este bloque se puede ver que archivos contienen el termino que queramos buscar en nuestro data frame
df[df.content.str.lower().str.contains('pobreza')].category.value_counts()
# Out:
# social      4
# interior    4
# Name: category, dtype: int64

# %%
#En este bloque entrenamos varios modelos (Random Forest, Naive Bayes, Regresion Logistica, Arbol de Decision y LinearSVC) para decidir cual es el mejor
models = [
    RandomForestClassifier(n_estimators=200, max_depth=5, min_samples_leaf=4 ,random_state=0),
    MultinomialNB(),
    LogisticRegression(random_state=0),
    DecisionTreeClassifier(),
    LinearSVC()
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

# %%
#En este bloque se muestra una grafica de la precision de los modelos entrenados
fig = plt.figure(figsize=(10,4))
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
# Out:
# <AxesSubplot:xlabel='model_name', ylabel='accuracy'>

# %%
#En este bloque se muestra los valores de precision de cada modelo
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# DecisionTreeClassifier    0.492826
# LinearSVC                 0.606053
# LogisticRegression        0.541521
# MultinomialNB             0.501459
# RandomForestClassifier    0.446989
# Name: accuracy, dtype: float64

# %%
#Dividimos los datos de entrenamiento y test, y realizamos el balanceo de los datos
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.1, random_state=42)
rus = RandomUnderSampler(random_state=42)
X_train, y_train = rus.fit_resample(X_train, y_train)

# %%
#En este bloque entrenamos otra vez con Naive Bayes y mostramos su matriz de confusión
model = MultinomialNB()
model.fit(X_train, y_train)
y_pred_proba = model.predict_proba(X_test)
y_pred = model.predict(X_test)

conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.category.values, yticklabels=category_id_df.category.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
print('Precision: %.3f' % precision_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
print('Recall: %.3f' % recall_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
print('F1 Score: %.3f' % f1_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
# Out:
# Precision: 0.650
# Recall: 0.486
# F1 Score: 0.497

# %%
#En este bloque entrenamos otra vez con Clasificación de vectores de soporte lineal y mostramos su matriz de confusión
model = LinearSVC()

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.category.values, yticklabels=category_id_df.category.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
print('Precision: %.3f' % precision_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
print('Recall: %.3f' % recall_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
print('F1 Score: %.3f' % f1_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
# Out:
# Precision: 0.547
# Recall: 0.486
# F1 Score: 0.503

# %%
#En este bloque entrenamos otra vez con Arbol de Decision y mostramos su matriz de confusión
model = DecisionTreeClassifier()

model.fit(X_train, y_train)
y_pred_proba = model.predict_proba(X_test)
y_pred = model.predict(X_test)

conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.category.values, yticklabels=category_id_df.category.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
print('Precision: %.3f' % precision_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
print('Recall: %.3f' % recall_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
print('F1 Score: %.3f' % f1_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
# Out:
# Precision: 0.517
# Recall: 0.314
# F1 Score: 0.335

# %%
#En este bloque entrenamos otra vez con Regresion Logistica y mostramos su matriz de confusión
model = LogisticRegression(random_state=0)

model.fit(X_train, y_train)
y_pred_proba = model.predict_proba(X_test)
y_pred = model.predict(X_test)

conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.category.values, yticklabels=category_id_df.category.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
print('Precision: %.3f' % precision_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
print('Recall: %.3f' % recall_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
print('F1 Score: %.3f' % f1_score(y_test, y_pred, average="weighted", labels=np.unique(y_pred), zero_division=0))
# Out:
# Precision: 0.599
# Recall: 0.543
# F1 Score: 0.556

# %%
#En este bloque testeamos el modelo que se ha decidido usar al final
texts = ["Nos gustaria mejorar las calles de nuestro barrio.",
         "Faltan hospitales en mi pueblo.",
         "Hay que fomentar la innovacion y el emprendimiento",
         "Apoyo a la investigacion de energias renovables.",
         "Ayudas para los desempleados de larga duración"]
text_features = tfidf.transform(texts)
predictions = model.predict(text_features)
for text, predicted in zip(texts, predictions):
  print('"{}"'.format(text))
  print("  - Se predice como: '{}'".format(id_to_category[predicted]))
  print("")
# Out:
# "Nos gustaria mejorar las calles de nuestro barrio."
#   - Se predice como: 'medioambiente'
#
# "Faltan hospitales en mi pueblo."
#   - Se predice como: 'sanidad'
#
# "Hay que fomentar la innovacion y el emprendimiento"
#   - Se predice como: 'medioambiente'
#
# "Apoyo a la investigacion de energias renovables."
#   - Se predice como: 'culturayciencia'
#
# "Ayudas para los desempleados de larga duración"
#   - Se predice como: 'social'
